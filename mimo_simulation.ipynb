# %% [markdown]
# <a href="https://colab.research.google.com/github/amarmohammed398/Robotics-Mimo-Simulation/blob/main/mimo_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MuJoCo Basics

# %% [markdown]
# ## 1. Installation

# %%
# !pip install mujoco

import os

# Set up GPU rendering.
# Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# This is usually installed as part of an Nvidia driver package, but the Colab
# kernel doesn't install its driver via APT, and as a result the ICD is missing.
# (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
  with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
    f.write("""{
    "file_format_version" : "1.0.0",
    "ICD" : {
        "library_path" : "libEGL_nvidia.so.0"
    }
}
""")

# Configure MuJoCo to use the EGL rendering backend (requires GPU)
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl

import mujoco

# Graphics and plotting.
print('Installing mediapy:')
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import mediapy as media
# Out:
# Collecting mujoco
#   Downloading mujoco-3.3.7-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.13.0)
# Collecting glfw (from mujoco)
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (3.23.0)
# Downloading mujoco-3.3.7-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 43.6 MB/s eta 0:00:00
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.10.0 mujoco-3.3.7
# Setting environment variable to use GPU rendering:
# env: MUJOCO_GL=egl
# Installing mediapy:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.3 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Defining and loading a simple model

# %%
xml = """
<mujoco>
  <worldbody>
    <light name="top" pos="0 0 1"/>
		<geom name="red_ball" mass=".5" type="sphere" size="0.05" rgba="1 0 0 1" pos="0 0 0.45"/>
    <geom name="green_cylinder" type="cylinder" size="0.05 0.2" rgba="0 1 0 1" pos="0 0 0.2"/>
  </worldbody>
</mujoco>
"""
# Make model and data
model = mujoco.MjModel.from_xml_string(xml)
data = mujoco.MjData(model)

# %% [markdown]
# The `xml` string is written in MuJoCo's [MJCF](http://www.mujoco.org/book/modeling.html), which is an [XML](https://en.wikipedia.org/wiki/XML#Key_terminology)-based modeling language.
#   - The only required element is `<mujoco>`. The smallest valid MJCF model is `<mujoco/>` which is a completely empty model.
#   - All physical elements live inside the `<worldbody>` which is always the top-level body and constitutes the global origin in Cartesian coordinates.
#   - We define two geom in the world named `red_ball` and `green_cylinder`.
#   - The MJCF language is described in the documentation's [XML Reference chapter](https://mujoco.readthedocs.io/en/latest/XMLreference.html).
#
# The `from_xml_string()` method invokes the model compiler, which creates a binary `mjModel` instance.

# %% [markdown]
# `mjData` contains the *state* and quantities that depend on it. The state is made up of time, [generalized](https://en.wikipedia.org/wiki/Generalized_coordinates) positions and generalized velocities. These are respectively `data.time`, `data.qpos` and `data.qvel`. In order to make a new `mjData`, all we need is our `mjModel`

# %% [markdown]
# ## 3. Rendering

# %%
# Make renderer, render and show the pixels
with mujoco.Renderer(model) as renderer:
  mujoco.mj_forward(model, data)
  renderer.update_scene(data)

  media.show_image(renderer.render())
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# ## 4. Simulation
#
# Now let's simulate and make a video. We'll use MuJoCo's main high level function `mj_step`, which steps the state $x_{t+h} = f(x_t)$.

# %%
def simulate_and_render(model, data, duration=3.8, framerate=60):
    # Initialize the frames list to store the video frames
    frames = []

    # Simulate and display video.
    mujoco.mj_resetData(model, data)  # Reset state and time.
    with mujoco.Renderer(model) as renderer:
      while data.time < duration:
        mujoco.mj_step(model, data)
        if len(frames) < data.time * framerate:
          renderer.update_scene(data)
          pixels = renderer.render()
          frames.append(pixels)

    media.show_video(frames, fps=framerate)
    return

simulate_and_render(model, data)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# Hmmm, the video is playing, but nothing is moving, why is that?
#
# This is because this model has no [degrees of freedom](https://www.google.com/url?sa=D&q=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FDegrees_of_freedom_(mechanics)) (DoFs). The things that move (and which have inertia) are called *bodies*. We add DoFs by adding *joints* to bodies, specifying how they can move with respect to their parents. Let's make a new body that contains our geoms, add a hinge joint and re-render, while visualizing the joint axis using the visualization option object `MjvOption`.

# %%
xml = """
<mujoco>
  <worldbody>
    <light name="top" pos="0 0 1"/>
    <body name="box_and_sphere" euler="0 0 -30">
      <joint name="swing" type="hinge" axis="1 -1 0" pos="-0.1 0 0"/>
		  <geom name="red_ball" mass=".5" type="sphere" size="0.05" rgba="1 0 0 1" pos="0 0 0.45"/>
      <geom name="green_cylinder" type="cylinder" size="0.05 0.2" rgba="0 1 0 1" pos="0 0 0.2"/>
    </body>
  </worldbody>
</mujoco>
"""
model = mujoco.MjModel.from_xml_string(xml)
data = mujoco.MjData(model)

# enable joint visualization option:
scene_option = mujoco.MjvOption()
scene_option.flags[mujoco.mjtVisFlag.mjVIS_JOINT] = True

simulate_and_render(model, data)
print('Total number of DoFs in the model:', model.nv)
print('Generalized positions:', data.qpos)
print('Generalized velocities:', data.qvel)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# Total number of DoFs in the model: 1
# Generalized positions: [-5.55252641]
# Generalized velocities: [1.7525444]

# %% [markdown]
# # MIMo

# %% [markdown]
# ## 1. Installation

# %%
# !git clone https://github.com/trieschlab/MIMo.git
import os
os.chdir('/content/MIMo')
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Cloning into 'MIMo'...
# remote: Enumerating objects: 2942, done.
# remote: Counting objects: 100% (637/637), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 2942 (delta 536), reused 447 (delta 433), pack-reused 2305 (from 3)
# Receiving objects: 100% (2942/2942), 98.75 MiB | 16.36 MiB/s, done.
# Resolving deltas: 100% (1702/1702), done.
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Collecting matplotlib==3.9.4 (from -r requirements.txt (line 2))
#   Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: imageio==2.37.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.37.0)
# Collecting scipy==1.13.1 (from -r requirements.txt (line 4))
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.7 MB/s eta 0:00:00
# Collecting trimesh==4.6.2 (from -r requirements.txt (line 5))
#   Downloading trimesh-4.6.2-py3-none-any.whl.metadata (18 kB)
# Collecting pyyaml==6.0.2 (from -r requirements.txt (line 6))
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting cachetools==5.5.1 (from -r requirements.txt (line 7))
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting CacheToolsUtils==6.0 (from -r requirements.txt (line 8))
#   Downloading CacheToolsUtils-6.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting networkx==3.2.1 (from -r requirements.txt (line 9))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting rtree==1.3.0 (from -r requirements.txt (line 10))
#   Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting mujoco==3.3.0 (from -r requirements.txt (line 11))
#   Downloading mujoco-3.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.2 MB/s eta 0:00:00
# Collecting gymnasium==0.28.1 (from -r requirements.txt (line 12))
#   Downloading gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable-baselines3==2.3.2 (from -r requirements.txt (line 13))
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting opencv-python-headless==4.11.0.86 (from -r requirements.txt (line 14))
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting torch==2.6.0 (from -r requirements.txt (line 15))
#   Downloading torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting scikit-image==0.24.0 (from -r requirements.txt (line 16))
#   Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: tensorboard==2.19.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (2.19.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->-r requirements.txt (line 11)) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->-r requirements.txt (line 11)) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->-r requirements.txt (line 11)) (3.1.10)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->-r requirements.txt (line 12))
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->-r requirements.txt (line 12)) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->-r requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->-r requirements.txt (line 12)) (0.0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2->-r requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r requirements.txt (line 15)) (3.20.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r requirements.txt (line 15)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r requirements.txt (line 15)) (75.2.0)
# Collecting sympy==1.13.1 (from torch==2.6.0->-r requirements.txt (line 15))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->-r requirements.txt (line 16)) (2025.10.4)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->-r requirements.txt (line 16)) (0.4)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.6.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard==2.19.0->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.0->-r requirements.txt (line 11)) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.0->-r requirements.txt (line 11)) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2->-r requirements.txt (line 13)) (2025.2)
# Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 103.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 26.2 MB/s eta 0:00:00
# Downloading trimesh-4.6.2-py3-none-any.whl (707 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.4/707.4 kB 54.7 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 62.0 MB/s eta 0:00:00
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading CacheToolsUtils-6.0-py3-none-any.whl (7.4 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.7 MB/s eta 0:00:00
# Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 45.5 MB/s eta 0:00:00
# Downloading mujoco-3.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 60.7 MB/s eta 0:00:00
# Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 54.7 MB/s eta 0:00:00
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 14.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 13.2 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.5 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 134.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 136.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 109.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 121.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.6 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 146.1 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 3.5 MB/s eta 0:00:00
# Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, trimesh, sympy, scipy, rtree, pyyaml, opencv-python-headless, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, jax-jumpy, cachetools, scikit-image, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, gymnasium, CacheToolsUtils, nvidia-cusolver-cu12, mujoco, torch, stable-baselines3
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.2
#     Uninstalling cachetools-5.5.2:
#       Successfully uninstalled cachetools-5.5.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.1
#     Uninstalling gymnasium-1.2.1:
#       Successfully uninstalled gymnasium-1.2.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: mujoco
#     Found existing installation: mujoco 3.3.7
#     Uninstalling mujoco-3.3.7:
#       Successfully uninstalled mujoco-3.3.7
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.28.1 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.6.0 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.6.0 which is incompatible.
# Successfully installed CacheToolsUtils-6.0 cachetools-5.5.1 gymnasium-0.28.1 jax-jumpy-1.0.0 matplotlib-3.9.4 mujoco-3.3.0 networkx-3.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencv-python-headless-4.11.0.86 pyyaml-6.0.2 rtree-1.3.0 scikit-image-0.24.0 scipy-1.13.1 stable-baselines3-2.3.2 sympy-1.13.1 torch-2.6.0 trimesh-4.6.2 triton-3.2.0
# Obtaining file:///content/MIMo
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (2.0.2)
# Requirement already satisfied: matplotlib==3.9.4 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (3.9.4)
# Requirement already satisfied: imageio==2.37.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (2.37.0)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (1.13.1)
# Requirement already satisfied: trimesh==4.6.2 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (4.6.2)
# Requirement already satisfied: pyyaml==6.0.2 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (6.0.2)
# Requirement already satisfied: cachetools==5.5.1 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (5.5.1)
# Requirement already satisfied: CacheToolsUtils==6.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (6.0)
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (3.2.1)
# Requirement already satisfied: rtree==1.3.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (1.3.0)
# Requirement already satisfied: mujoco==3.3.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (3.3.0)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (0.28.1)
# Requirement already satisfied: stable-baselines3==2.3.2 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (2.3.2)
# Requirement already satisfied: opencv-python-headless==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (4.11.0.86)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (2.6.0)
# Requirement already satisfied: scikit-image==0.24.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (0.24.0)
# Requirement already satisfied: tensorboard==2.19.0 in /usr/local/lib/python3.12/dist-packages (from MIMo==2.0.0) (2.19.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->MIMo==2.0.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->MIMo==2.0.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->MIMo==2.0.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->MIMo==2.0.0) (0.0.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio==2.37.0->MIMo==2.0.0) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.4->MIMo==2.0.0) (2.9.0.post0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->MIMo==2.0.0) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->MIMo==2.0.0) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->MIMo==2.0.0) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco==3.3.0->MIMo==2.0.0) (3.1.10)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->MIMo==2.0.0) (2025.10.4)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->MIMo==2.0.0) (0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2->MIMo==2.0.0) (2.2.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->MIMo==2.0.0) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (3.20.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->MIMo==2.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.6.0->MIMo==2.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard==2.19.0->MIMo==2.0.0) (3.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.0->MIMo==2.0.0) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco==3.3.0->MIMo==2.0.0) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2->MIMo==2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2->MIMo==2.0.0) (2025.2)
# Installing collected packages: MIMo
#   Running setup.py develop for MIMo
# Successfully installed MIMo-2.0.0

# %% [markdown]
# ## 2. Import dependencies

# %%
import gymnasium as gym
import time
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

import mimoEnv
from mimoEnv.envs.mimo_env import MIMoEnv
from mimoActuation.actuation import SpringDamperModel
from mimoActuation.muscle import MuscleModel
from stable_baselines3 import PPO as RL
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 3. Load and Control MIMo Model

# %%
os.chdir("/content/MIMo/mimoEnv/assets/")
xml = """
<mujoco>
	<include file="mimo/MIMo_meta.xml"></include>
  <worldbody>
    <light name="top" pos="0 0 1"/>
		<body name="mimo_location" pos="0 0 0.3" euler="0 0 0">
			<freejoint name="mimo_orientation"/>
			<include file="mimo/MIMo_model.xml"></include> <!-- Import the actual model-->
		</body>
  </worldbody>
</mujoco>
"""
model = mujoco.MjModel.from_xml_string(xml)
data = mujoco.MjData(model)
# simulate_and_render(model, data)

# %%
# Make renderer, render and show the pixels
with mujoco.Renderer(model) as renderer:
  mujoco.mj_forward(model, data)
  renderer.update_scene(data)
  img_before = renderer.render()
media.show_image(img_before)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="240" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# ### Manually Set Joint Position

# %% [markdown]
# **List all joints in the model**

# %%
for i in range(model.njnt):  # model.njnt gives the number of joints
    joint_name = mujoco.mj_id2name(model, mujoco.mjtObj.mjOBJ_JOINT, i)
    print(f"Joint {i}: {joint_name}")
# Out:
# Joint 0: mimo_orientation
# Joint 1: robot:hip_lean1
# Joint 2: robot:hip_rot1
# Joint 3: robot:hip_bend1
# Joint 4: robot:hip_lean2
# Joint 5: robot:hip_rot2
# Joint 6: robot:hip_bend2
# Joint 7: robot:chest_lean
# Joint 8: robot:chest_rot
# Joint 9: robot:right_shoulder_horizontal
# Joint 10: robot:right_shoulder_ad_ab
# Joint 11: robot:right_shoulder_rotation
# Joint 12: robot:right_elbow
# Joint 13: robot:right_hand1
# Joint 14: robot:right_hand2
# Joint 15: robot:right_hand3
# Joint 16: robot:right_fingers
# Joint 17: robot:left_shoulder_horizontal
# Joint 18: robot:left_shoulder_ad_ab
# Joint 19: robot:left_shoulder_rotation
# Joint 20: robot:left_elbow
# Joint 21: robot:left_hand1
# Joint 22: robot:left_hand2
# Joint 23: robot:left_hand3
# Joint 24: robot:left_fingers
# Joint 25: robot:head_swivel
# Joint 26: robot:head_tilt
# Joint 27: robot:head_tilt_side
# Joint 28: robot:left_eye_horizontal
# Joint 29: robot:left_eye_vertical
# Joint 30: robot:left_eye_torsional
# Joint 31: robot:right_eye_horizontal
# Joint 32: robot:right_eye_vertical
# Joint 33: robot:right_eye_torsional
# Joint 34: robot:right_hip1
# Joint 35: robot:right_hip2
# Joint 36: robot:right_hip3
# Joint 37: robot:right_knee
# Joint 38: robot:right_foot1
# Joint 39: robot:right_foot2
# Joint 40: robot:right_foot3
# Joint 41: robot:right_toes
# Joint 42: robot:left_hip1
# Joint 43: robot:left_hip2
# Joint 44: robot:left_hip3
# Joint 45: robot:left_knee
# Joint 46: robot:left_foot1
# Joint 47: robot:left_foot2
# Joint 48: robot:left_foot3
# Joint 49: robot:left_toes

# %% [markdown]
# [link text](https://)**Set the head tilt angle to 45 degrees**

# %%
head_tilt_name = "robot:head_tilt"  # Correct joint name (after checking the print output)
joint_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_JOINT, head_tilt_name) # Get the joint ID
qpos_index = model.jnt_qposadr[joint_id]  # Get the qpos index for this joint - array that stores the position for all joints
data.qpos[qpos_index] = np.deg2rad(45)  # Convert degrees to radians
mujoco.mj_step(model, data) # Step the simulation to apply changes

# %%
# Make renderer, render and show the pixels
with mujoco.Renderer(model) as renderer:
  mujoco.mj_forward(model, data)
  renderer.update_scene(data)
  img_after = renderer.render()

# Plot side-by-side comparison
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(img_before)
ax[0].set_title("Before Head Tilt")
ax[0].axis("off")
ax[1].imshow(img_after)
ax[1].set_title("After Head Tilt (45°)")
ax[1].axis("off")
plt.show()

# %%
joint_name = "robot:right_shoulder_horizontal"  # Correct joint name (after checking the print output)
joint_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_JOINT, joint_name) # Get the joint ID
qpos_index = model.jnt_qposadr[joint_id]  # Get the qpos index for this joint
data.qpos[qpos_index] = np.deg2rad(45)  # Convert degrees to radians
mujoco.mj_step(model, data) # Step the simulation to apply changes
# Render the updated model
with mujoco.Renderer(model) as renderer:
    mujoco.mj_forward(model, data)
    renderer.update_scene(data)
    img_after = renderer.render()

# Display the modified model
import matplotlib.pyplot as plt

plt.imshow(img_after)
plt.title("Right Shoulder Abduction (45°)")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 4. Load Environment

# %%
os.chdir('/content/MIMo')
env_name = 'catch'             #choices=['reach', 'standup', 'selfbody', 'catch']
actuation_model = SpringDamperModel

save_dir = os.path.join("models", env_name)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

env_names = {"reach": "MIMoReach-v0",
        "standup": "MIMoStandup-v0",
        "selfbody": "MIMoSelfBody-v0",
        "catch": "MIMoCatch-v0"}

env_name = 'reach'
env = gym.make(env_names[env_name], actuation_model=actuation_model)
env.reset()


env = gym.make(env_names[env_name], actuation_model=actuation_model, render_mode="rgb_array")
env.reset()
# Out:
# ({'observation': array([-2.10750327e-01,  5.23036301e-01, -4.86081570e-01,  1.09076127e-01,
#           9.29097116e-01, -2.60654628e-01,  3.09840590e-01, -7.15909123e-01,
#          -4.05541922e-01,  2.23659226e+00, -1.29910471e+00,  4.23170907e-01,
#           6.66855202e-01, -3.31405352e-01,  3.01810474e-01, -5.06499918e-01,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00,  1.73112882e-02, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  2.73730975e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  4.65169998e-01,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -7.77884358e-04, -3.80188342e-03,  7.71827184e-03,
#          -1.35731571e-03, -4.59306003e-03,  2.24519801e-04, -1.22685528e-01,
#           5.18965057e-02,  0.00000000e+00, -1.03530332e-01,  0.00000000e+00,
#           3.28652462e-02, -1.03530332e-01,  0.00000000e+00,  0.00000000e+00,
#          -1.30637462e-02, -1.38771160e-01,  3.15506498e-01, -4.32210477e-01,
#           1.48072304e-01,  6.09993896e-01, -3.12074529e-01,  2.66725915e-01,
#           1.20907290e-01,  4.49659023e-02, -3.33460003e-02, -1.19030219e-01,
#          -2.24934946e-06,  1.84889164e-07, -6.45593022e-05,  2.24934946e-06,
#           1.84889164e-07,  6.45593022e-05, -1.34149296e-02, -1.47717078e-03,
#           9.47411555e-04, -3.91890917e-02,  5.96095164e-03,  3.61033255e-03,
#          -2.58883201e-03,  4.14087118e-06, -1.37066643e-02, -6.22138528e-05,
#          -7.61808969e-04, -3.77851176e-02,  6.38674219e-03,  1.22595365e-02,
#           2.58966217e-03, -4.66914775e-05,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -4.10888855e-01,
#          -2.73865923e-02,  1.51161039e-02,  1.32347487e-05,  1.48062774e-06,
#          -5.39794943e-06,  1.32347487e-05,  1.48062774e-06, -5.39794943e-06,
#           4.84678160e+00, -6.84642725e-01, -2.77096180e+00,  8.53656810e+00,
#          -6.10911730e-01, -3.05778955e+00,  4.95063442e+00,  1.29504814e+01,
#           3.45207297e+00, -7.06060157e+00,  3.47079974e-01, -1.00701285e-02,
#          -1.60798891e+00,  2.30544626e-01,  4.69737456e-02,  6.95433398e-01,
#          -6.16118564e-02, -3.05525768e-02,  2.22922343e+00, -9.36386810e+00,
#           3.59589106e+00,  3.12189891e+01,  8.78516122e+00, -2.82061377e+00,
#          -4.65397904e-01,  9.64790582e-01, -2.79559172e+00,  7.16619185e-02,
#          -3.24822487e-02, -1.56505282e-03,  3.03015484e-01,  4.32337558e-01,
#          -1.97542090e-02,  2.69565359e-01,  8.11912134e-01, -6.87867707e-03,
#           4.50608804e-01,  7.17601985e-01, -1.13071716e-02, -9.51021813e-05,
#          -1.97064802e-04, -9.66126081e-05, -1.30119207e-02,  3.69882186e-01,
#           6.19759664e-03, -4.92714698e-02,  7.75982170e-01,  6.24254949e-03,
#           1.26451811e-01,  6.60279181e-01,  1.44781619e-02, -5.26523549e-05,
#           3.21595713e-04,  4.01895560e-05])},
#  {})

# %%
model = env.unwrapped.model
data = env.unwrapped.data
simulate_and_render(model, data)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
env.action_space
# Out:
# Box([-1.     -0.6875 -1.     -1.     -1.     -1.     -0.87   -1.    ], [1.   1.   0.64 0.83 1.   0.57 1.   0.33], (8,), float32)

# %%
env.action_space.sample()
# Out:
# array([ 0.22943816,  0.90877724, -0.47227412, -0.95821035,  0.5052106 ,
#         0.5200855 ,  0.17559102,  0.31940475], dtype=float32)

# %%
env.reset()
# Out:
# ({'observation': array([-4.27031457e-01,  6.29639328e-01,  4.28047866e-01, -6.01062894e-01,
#          -5.79801202e-01, -5.44556320e-01,  9.59532917e-01,  1.69947296e-01,
#          -8.21726642e-01,  2.69244495e+00,  1.14400346e+00, -2.33187899e+00,
#          -4.16149659e-01, -6.92367828e-01,  9.34664773e-01,  1.20236338e-01,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00,  3.56247843e-02, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  2.44917405e-01,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  2.07954266e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  3.78805494e-01,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -8.03638301e-04, -4.61537954e-03,  7.30821362e-03,
#          -1.34758966e-03, -3.55170348e-03,  3.26340717e-04, -1.23326500e-01,
#           5.19791801e-02,  0.00000000e+00, -1.03755402e-01,  0.00000000e+00,
#           6.08385718e-02, -1.03755402e-01,  0.00000000e+00,  0.00000000e+00,
#          -2.62896458e-02, -1.47058820e-01,  3.15058056e-01, -4.40266346e-01,
#           1.25050456e-01,  6.23200117e-01, -3.18236644e-01,  2.53251107e-01,
#           1.17884532e-01,  4.52051342e-02, -3.53264764e-02, -1.17963623e-01,
#          -3.24925461e-06, -2.06914825e-07, -6.36149700e-05,  3.24925461e-06,
#          -2.06914825e-07,  6.36149700e-05, -1.33747371e-02, -1.53933969e-03,
#           1.12237115e-03, -3.86346329e-02,  6.42265523e-03,  3.81235036e-03,
#          -3.05609306e-03,  8.68135738e-06, -1.38065981e-02, -3.05857026e-05,
#          -9.37132810e-04, -3.71665400e-02,  6.71318079e-03,  1.23295798e-02,
#           3.06458335e-03, -4.20002185e-05,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -4.04273508e-01,
#          -9.29666973e-02, -2.62233501e-02,  1.28596755e-05,  4.71414565e-06,
#          -8.64483197e-06,  1.28596755e-05,  4.71414565e-06, -8.64483197e-06,
#           4.80770313e+00, -7.36889037e-01, -4.18123719e+00,  8.48006588e+00,
#          -6.41254237e-01, -4.66963740e+00,  4.44578553e+00,  1.32775956e+01,
#           2.46802866e+00, -6.94366519e+00,  1.82895217e+00,  2.44649662e-02,
#          -1.51033174e+00,  6.95695621e-01,  7.91629746e-02, -4.54289171e-02,
#           1.16878314e-01, -1.43640533e-02,  2.54437420e+00, -9.84181879e+00,
#           3.69943718e+00,  3.19314304e+01,  9.97690458e+00, -2.80522737e+00,
#          -4.83967653e-01,  9.08024375e-01, -2.78783067e+00,  7.10578305e-02,
#          -3.42459458e-02, -1.60772929e-03,  3.09739556e-01,  4.37387762e-01,
#          -1.73466783e-02,  2.77706164e-01,  8.06020880e-01, -4.03825258e-03,
#           4.54735923e-01,  7.21561989e-01, -8.77409693e-03, -9.22974940e-05,
#          -1.99237080e-04, -9.81375208e-05, -1.74022735e-02,  3.73430579e-01,
#           4.62860306e-03, -4.97711039e-02,  7.69869636e-01,  4.95109633e-03,
#           1.25517892e-01,  6.62061749e-01,  1.32962732e-02, -5.24908389e-05,
#           3.13404920e-04,  2.91299451e-05])},
#  {})

# %% [markdown]
# **Understanding the Environment**
#
# The scene configuration for the `catch` action is defined in the files `catch_scene.xml` and `catch_meta.xml`, which are located in the `mimoEnv/assets/` directory.

# %%
# Find the actuator ID
actuator_name = "act:right_wrist_rotation"
actuator_id = mujoco.mj_name2id(model, mujoco.mjtObj.mjOBJ_ACTUATOR, actuator_name)

# Modify gear ratio
model.actuator_gear[actuator_id, 0] = -0.7

# %% [markdown]
# ## 5. Train an RL model

# %% [markdown]
# Simple training and testing of RL algorithms in the demo environments.
#   - A selection of RL algorithms from the Stable Baselines3 library can be selected.
#   - Trained models are saved into the "/content/MIMo/mimoEnv/models/<scenario>" directory

# %%
model = RL("MultiInputPolicy", env, tensorboard_log=os.path.join("models", "tensorboard_logs", env_name), verbose=1)
train_for = 200000             # Total timesteps of training
save_every = 200000
# train model
counter = 0
while train_for > 0: # model trained using 1 chunk and then saved at the end. To save and train periodically, update save_every to 50k for 4 chunks and 4 saves.
    counter += 1
    train_for_iter = min(train_for, save_every)
    train_for = train_for - train_for_iter
    model.learn(total_timesteps=train_for_iter, reset_num_timesteps=False)
    model.save(os.path.join(save_dir, "model_" + str(counter)))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to models/tensorboard_logs/reach/PPO_0
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -277     |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 392      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -267        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015281191 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.20335168  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.312       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0349     |
# |    std                  | 1           |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 950         |
# |    ep_rew_mean          | -219        |
# |    success_rate         | 0.167       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013019675 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 0.60893595  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.341       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 1           |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 962         |
# |    ep_rew_mean          | -207        |
# |    success_rate         | 0.125       |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011345983 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.026127517 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.85        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.996       |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -213        |
# |    success_rate         | 0.1         |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016114643 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.85189545  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.994       |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | -210        |
# |    success_rate         | 0.0833      |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 6           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016984127 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.8378669   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.034      |
# |    std                  | 0.989       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 978        |
# |    ep_rew_mean          | -206       |
# |    success_rate         | 0.0714     |
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 7          |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01783615 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.2      |
# |    explained_variance   | 0.23479813 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.173      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0397    |
# |    std                  | 0.984      |
# |    value_loss           | 0.862      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 981         |
# |    ep_rew_mean          | -210        |
# |    success_rate         | 0.0625      |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 8           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019547902 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.16045213  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0248      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0411     |
# |    std                  | 0.982       |
# |    value_loss           | 0.593       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 983         |
# |    ep_rew_mean          | -211        |
# |    success_rate         | 0.0556      |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 9           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016093666 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.81818146  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.032      |
# |    std                  | 0.981       |
# |    value_loss           | 0.921       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | -216        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 10          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021673398 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.9141543   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0446     |
# |    std                  | 0.976       |
# |    value_loss           | 0.408       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | -212        |
# |    success_rate         | 0.0455      |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019225802 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.77575153  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00595    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0439     |
# |    std                  | 0.971       |
# |    value_loss           | 0.357       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 987         |
# |    ep_rew_mean          | -209        |
# |    success_rate         | 0.0417      |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 12          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016295735 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.9580195   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0929      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.965       |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 988         |
# |    ep_rew_mean          | -206        |
# |    success_rate         | 0.0385      |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 13          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016394116 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.90663487  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.962       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 989         |
# |    ep_rew_mean          | -203        |
# |    success_rate         | 0.0357      |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 14          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020584315 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.77094024  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0306      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 0.96        |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | -198        |
# |    success_rate         | 0.0323      |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 15          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.022650776 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.8142843   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00977    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 0.952       |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -196        |
# |    success_rate         | 0.0303      |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 16          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016463798 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.39134216 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00724    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.952       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -196        |
# |    success_rate         | 0.0286      |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 17          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023873735 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.6120815   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0644     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0487     |
# |    std                  | 0.951       |
# |    value_loss           | 0.0504      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -195        |
# |    success_rate         | 0.027       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 18          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021215621 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.5986154   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0453     |
# |    std                  | 0.953       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | -187        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 19          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025545388 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.09249705  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0181      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0501     |
# |    std                  | 0.949       |
# |    value_loss           | 0.445       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | -185        |
# |    success_rate         | 0.0476      |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 20          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016538793 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.10928905  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.948       |
# |    value_loss           | 33.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 964         |
# |    ep_rew_mean          | -180        |
# |    success_rate         | 0.0682      |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 21          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017063458 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.4683094   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0906      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.949       |
# |    value_loss           | 0.383       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 965           |
# |    ep_rew_mean          | -178          |
# |    success_rate         | 0.0652        |
# | time/                   |               |
# |    fps                  | 341           |
# |    iterations           | 22            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.01503171    |
# |    clip_fraction        | 0.117         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -10.9         |
# |    explained_variance   | -0.0033408403 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.569         |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.0132       |
# |    std                  | 0.949         |
# |    value_loss           | 38.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | -176        |
# |    success_rate         | 0.0625      |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 23          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013692323 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.7684241   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.947       |
# |    value_loss           | 0.656       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | -176        |
# |    success_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 24          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021225441 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.91734564  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00808    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 0.943       |
# |    value_loss           | 0.256       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | -174        |
# |    success_rate         | 0.0577      |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 25          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.024205795 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.830824    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00799    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.944       |
# |    value_loss           | 0.221       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 970        |
# |    ep_rew_mean          | -174       |
# |    success_rate         | 0.0556     |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 26         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02352161 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.9      |
# |    explained_variance   | 0.8331401  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0539    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0336    |
# |    std                  | 0.942      |
# |    value_loss           | 0.133      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.0536      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 27          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.024081951 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | -1.2712123  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0371     |
# |    std                  | 0.938       |
# |    value_loss           | 0.444       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 972        |
# |    ep_rew_mean          | -173       |
# |    success_rate         | 0.0517     |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 28         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03298866 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.8      |
# |    explained_variance   | 0.71648777 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0378    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0481    |
# |    std                  | 0.927      |
# |    value_loss           | 0.104      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 973         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 29          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.030450923 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.96371824  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.042      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0427     |
# |    std                  | 0.923       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.0476      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 30          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.029805042 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.89635795  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.922       |
# |    value_loss           | 0.0626      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | -170        |
# |    success_rate         | 0.0462      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 31          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.025773231 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.2595945   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0293     |
# |    std                  | 0.919       |
# |    value_loss           | 0.0791      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 976         |
# |    ep_rew_mean          | -170        |
# |    success_rate         | 0.0448      |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 32          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.030081835 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.9734515   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0361     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0468     |
# |    std                  | 0.918       |
# |    value_loss           | 0.0679      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.0435      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 33          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.027925571 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.992541    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.039      |
# |    std                  | 0.914       |
# |    value_loss           | 0.0254      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.0423      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 34          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022678036 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -2.9953334  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00653    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.91        |
# |    value_loss           | 0.0649      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.0411      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 35          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.021318413 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -1.0302048  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.362       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0342     |
# |    std                  | 0.909       |
# |    value_loss           | 2.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 979        |
# |    ep_rew_mean          | -172       |
# |    success_rate         | 0.04       |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 36         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03050497 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.6      |
# |    explained_variance   | 0.83278406 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0377    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0412    |
# |    std                  | 0.911      |
# |    value_loss           | 0.0692     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 979         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.039       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 37          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.032565437 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.9501497   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0381     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0404     |
# |    std                  | 0.91        |
# |    value_loss           | 0.0436      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 980         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.038       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 38          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.030070715 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.75561786  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.092      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0451     |
# |    std                  | 0.908       |
# |    value_loss           | 0.0208      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 980         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.037       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 39          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.030055601 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.95037305  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0465     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 0.905       |
# |    value_loss           | 0.0356      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 981        |
# |    ep_rew_mean          | -171       |
# |    success_rate         | 0.0361     |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 40         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03171966 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.5      |
# |    explained_variance   | 0.8655991  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0577    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0451    |
# |    std                  | 0.906      |
# |    value_loss           | 0.0542     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 981         |
# |    ep_rew_mean          | -171        |
# |    success_rate         | 0.0353      |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 41          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.030676246 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -2.1370945  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.906       |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.0345      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 42          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.032004047 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | -0.10341668 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00181    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0315     |
# |    std                  | 0.902       |
# |    value_loss           | 0.619       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -172        |
# |    success_rate         | 0.0337      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 43          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.033172783 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.14470273  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0929     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0564     |
# |    std                  | 0.9         |
# |    value_loss           | 0.0258      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 982         |
# |    ep_rew_mean          | -170        |
# |    success_rate         | 0.033       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 44          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023508554 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.5917615   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0464     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.896       |
# |    value_loss           | 0.0484      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 983         |
# |    ep_rew_mean          | -170        |
# |    success_rate         | 0.0323      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 45          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026349716 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.45172274  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0316     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0375     |
# |    std                  | 0.898       |
# |    value_loss           | 0.0655      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 974         |
# |    ep_rew_mean          | -167        |
# |    success_rate         | 0.0417      |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 46          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030931575 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.32969314  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0438     |
# |    std                  | 0.899       |
# |    value_loss           | 0.0735      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | -167         |
# |    success_rate         | 0.0408       |
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 47           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.020250387  |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | -0.025580406 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.14         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0152      |
# |    std                  | 0.9          |
# |    value_loss           | 38.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 975        |
# |    ep_rew_mean          | -167       |
# |    success_rate         | 0.04       |
# | time/                   |            |
# |    fps                  | 343        |
# |    iterations           | 48         |
# |    time_elapsed         | 286        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.04277744 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.5      |
# |    explained_variance   | 0.73368204 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0947    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0623    |
# |    std                  | 0.894      |
# |    value_loss           | 0.0556     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | -166        |
# |    success_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 49          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.028035395 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.5272267   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0536     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0463     |
# |    std                  | 0.891       |
# |    value_loss           | 0.0181      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | -163         |
# |    success_rate         | 0.04         |
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 50           |
# |    time_elapsed         | 298          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.026380403  |
# |    clip_fraction        | 0.252        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.4        |
# |    explained_variance   | -0.124645114 |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0056      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0368      |
# ...
# | train/                  |            |
# |    approx_kl            | 0.04259631 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.95      |
# |    explained_variance   | 0.6716442  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0376    |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.0209    |
# |    std                  | 0.843      |
# |    value_loss           | 0.0678     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -155        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 83          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.034322467 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.92       |
# |    explained_variance   | 0.086520016 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.839       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -155        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 84          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.037154876 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.91       |
# |    explained_variance   | 0.30292833  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0585      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.032      |
# |    std                  | 0.839       |
# |    value_loss           | 0.702       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | -155       |
# |    success_rate         | 0.05       |
# | time/                   |            |
# |    fps                  | 346        |
# |    iterations           | 85         |
# |    time_elapsed         | 502        |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.04883413 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.93      |
# |    explained_variance   | 0.3471669  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0595    |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.0432    |
# |    std                  | 0.842      |
# |    value_loss           | 0.0265     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | -156         |
# |    success_rate         | 0.05         |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 86           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.052477136  |
# |    clip_fraction        | 0.399        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.97        |
# |    explained_variance   | -0.038323283 |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0215      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0344      |
# |    std                  | 0.847        |
# |    value_loss           | 0.0595       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | -155       |
# |    success_rate         | 0.05       |
# | time/                   |            |
# |    fps                  | 346        |
# |    iterations           | 87         |
# |    time_elapsed         | 514        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.03911946 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.96      |
# |    explained_variance   | 0.85100716 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0906    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0439    |
# |    std                  | 0.844      |
# |    value_loss           | 0.0136     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -154        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 88          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.035857707 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.93       |
# |    explained_variance   | -0.25223315 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0456     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.841       |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -153        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 89          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.038531072 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.91       |
# |    explained_variance   | 0.4060611   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.065      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0436     |
# |    std                  | 0.839       |
# |    value_loss           | 0.0487      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -153        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 90          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.054895464 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.9        |
# |    explained_variance   | 0.6584711   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00843     |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.838       |
# |    value_loss           | 0.259       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | -154        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 91          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.040299572 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.88       |
# |    explained_variance   | -0.7895268  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.835       |
# |    value_loss           | 0.0449      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 957        |
# |    ep_rew_mean          | -153       |
# |    success_rate         | 0.05       |
# | time/                   |            |
# |    fps                  | 346        |
# |    iterations           | 92         |
# |    time_elapsed         | 543        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.03676428 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.87      |
# |    explained_variance   | -1.5529332 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0236    |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0293    |
# |    std                  | 0.837      |
# |    value_loss           | 0.0509     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 966        |
# |    ep_rew_mean          | -157       |
# |    success_rate         | 0.04       |
# | time/                   |            |
# |    fps                  | 346        |
# |    iterations           | 93         |
# |    time_elapsed         | 549        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.03909547 |
# |    clip_fraction        | 0.332      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.88      |
# |    explained_variance   | 0.07769483 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0717    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0393    |
# |    std                  | 0.837      |
# |    value_loss           | 0.0437     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | -157        |
# |    success_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 94          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.037654385 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.89       |
# |    explained_variance   | 0.73951614  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0905      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 0.838       |
# |    value_loss           | 0.502       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | -155        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 95          |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.046333913 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.89       |
# |    explained_variance   | 0.42496902  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0507     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0348     |
# |    std                  | 0.838       |
# |    value_loss           | 0.0316      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 958           |
# |    ep_rew_mean          | -154          |
# |    success_rate         | 0.05          |
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 96            |
# |    time_elapsed         | 566           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.020644905   |
# |    clip_fraction        | 0.228         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.89         |
# |    explained_variance   | -0.0037904978 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.86          |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -0.0149       |
# |    std                  | 0.839         |
# |    value_loss           | 37            |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | -155        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 97          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.03461641  |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.9        |
# |    explained_variance   | -0.17245972 |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.042      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.84        |
# |    value_loss           | 0.0402      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | -154        |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 98          |
# |    time_elapsed         | 578         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.028806783 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.9        |
# |    explained_variance   | 0.81953144  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.958       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.839       |
# |    value_loss           | 2.13        |
# -----------------------------------------

# %% [markdown]
# **Understanding [Training Metrics](https://stable-baselines3.readthedocs.io/en/master/common/logger.html#explanation-of-logger-output) **
#
#
# *  Evaluation Metrics:
# Ep_len_mean, ep_rew_mean
# *  Time Metrics:
# Fps, iterations, time_elapsed, total_timesteps
# *  Loss Metrics:
# Entropy_loss, policy_loss, value_loss
# *  Other Metrics：
# Explained_variance, Learning_rate, n_updates

# %% [markdown]
# ## 6. Test Model

# %%
def test(env, save_dir, test_for=1000, model=None, render_video=False):
    """ Testing function to view the behaviour of a model.

    Args:
        env (MIMoEnv): The environment on which the model should be tested. This does not have to be the same training
            environment, but action and observation spaces must match.
        save_dir (str): The directory in which any rendered videos will be saved.
        test_for (int): The number of timesteps the testing runs in total. This will be broken into multiple episodes
            if necessary.
        model:  The stable baselines model object. If ``None`` we take random actions instead. Default ``None``.
        render_video (bool): If ``True``, all episodes during testing will be recorded and saved as videos in
            `save_dir`.
    """
    obs, _ = env.reset()
    images = []
    im_counter = 0

    for idx in range(test_for):
        if model is None:
            print("No model, taking random actions")
            action = env.action_space.sample()
        else:
            action, _ = model.predict(obs)
        obs, _, done, trunc, _ = env.step(action)
        if render_video:
            img = env.mujoco_renderer.render(render_mode="rgb_array")
            images.append(img)
        if done or trunc:
            time.sleep(1)
            obs, _ = env.reset()
            if render_video:
                fourcc = cv2.VideoWriter_fourcc(*'mp4v')
                video = cv2.VideoWriter(os.path.join(save_dir, 'episode_{}.avi'.format(im_counter)), fourcc, 50, (500, 500))
                for img in images:
                    video.write(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
                # cv2.destroyAllWindows()
                video.release()

                images = []
                im_counter += 1

    env.reset()

test(env, save_dir, model=model, test_for=100, render_video=True)

# %% [markdown]
# Rendered test example videos are stored in the `model/catch` directory.

# %%
def test(env, test_for, model=None):
    obs, _ = env.reset()
    images = []
    im_counter = 0

    for idx in range(test_for):
      if model is None:
          print("No model, taking random actions")
          action = env.action_space.sample()
      else:
          action, _ = model.predict(obs)
      obs, _, done, trunc, _ = env.step(action)
      img = env.mujoco_renderer.render(render_mode="rgb_array")
      images.append(img)

      if done or trunc:
          env.reset()
          break  # End episode
    media.show_video(images, fps=60)

test(env, model=model, test_for=100)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="500" height="500" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# ## Practices
# 1. Using an alternative [RL algorithm](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html)
# 2. [Try other tasks](https://github.com/trieschlab/MIMo)
#
# * **reach** - A stripped down version where MIMo is tasked with reaching for a ball hovering in front of him. By default, only the proprioceptive sensors are used. MIMo can only move his right arm and his head is manually fixed to track the ball. The initial position of both the ball and MIMo is slightly randomized.
#
# * **standup** - MIMo is tasked with standing up. At the start he is in a low crouch with his hands gripping the bars of a crib. Proprioception and the vestibular sensors are included by default.
#
# * **selfbody** - MIMo is sitting on the ground and rewarded for touching a specific body part with his right arm. The target body part is randomized each episode.
